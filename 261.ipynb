# %%
from numpy import random
x=random.randint(100)
print(x)
# Out:
# 29

# %%
from numpy import random
x=random.rand(100)
print(x)
# Out:
# [0.27149166 0.97418054 0.32284986 0.79930386 0.2456579  0.97148602
#  0.47370671 0.57129333 0.1219283  0.04492399 0.56109703 0.39648207
#  0.15146907 0.99226301 0.27806201 0.96401815 0.03083105 0.73824807
#  0.21711259 0.83268989 0.92578402 0.68976338 0.53085959 0.24340514
#  0.69966806 0.82521539 0.02387572 0.60155161 0.2706809  0.31829633
#  0.47362118 0.92289922 0.48595999 0.98430452 0.51146596 0.65672932
#  0.54810823 0.84228242 0.80264954 0.65102558 0.66394836 0.82626617
#  0.84235139 0.46745403 0.41663916 0.75998891 0.54650467 0.27996462
#  0.63042891 0.59895375 0.9500755  0.12118234 0.61127849 0.33419138
#  0.86261026 0.66370476 0.11989629 0.30294234 0.23061999 0.45852895
#  0.74845072 0.92576014 0.26399853 0.58580337 0.55423806 0.39784161
#  0.21739318 0.01685562 0.66387738 0.17767252 0.60481682 0.68558371
#  0.87137235 0.43215166 0.31955931 0.64232236 0.67287485 0.09990881
#  0.43642292 0.98526536 0.76472193 0.40140944 0.24358954 0.42430272
#  0.38190282 0.8921944  0.31899982 0.07514747 0.3963631  0.7392559
#  0.12096304 0.51672331 0.70161377 0.51661495 0.53495405 0.07850629
#  0.30637801 0.7180007  0.04893251 0.64890588]

# %%
from numpy import random
x=random.choice([3,5,7,9],p=[0.1,0.3,0.6,0.0],size=(100))
print(x)
# Out:
# [5 5 7 7 7 3 5 5 7 7 7 7 7 7 7 7 7 5 7 3 7 7 7 5 5 7 5 7 7 7 7 7 5 7 7 3 7
#  7 7 7 5 7 5 5 7 5 7 3 3 5 7 7 7 5 7 5 5 7 7 7 7 3 7 5 7 7 7 5 5 3 5 7 7 7
#  5 7 7 5 5 7 5 7 7 7 7 7 5 7 5 7 7 7 7 5 7 7 7 7 7 5]

# %%
from numpy import random
x=random.choice([2,4,5,6],p=[0.1,0.3,0.6,0.0],size=(3,5))
print(x)
# Out:
# [[4 5 4 4 5]
#  [4 5 5 4 4]
#  [2 4 4 5 5]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.normal(size=1000),hist=False)
plt.show()
# Out:
# C:\Users\rajes\AppData\Local\Temp\ipykernel_23884\474875161.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000),hist=False)

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.normal(size=1000),hist=True)
plt.show()
# Out:
# C:\Users\rajes\AppData\Local\Temp\ipykernel_23884\2633877717.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000),hist=True)

# %%
from numpy import random
x=random.binomial(n=10,p=0.5,size=10)
print(x)
# Out:
# [2 5 4 6 5 4 8 7 5 4]
